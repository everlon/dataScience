# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20200101', periods=600, freq="D")
df = pd.DataFrame(np.random.randn(600,5), index=datas, columns=list("ABCDE"))
df.head(5)
# Out:
#                    A         B         C         D         E
# 2020-01-01 -1.125108  2.307343  0.309759  0.057440 -1.616780
# 2020-01-02  0.328071  0.796712 -0.064047 -0.795155 -0.447193
# 2020-01-03 -0.800781 -1.367413  0.845610  0.121914  0.595674
# 2020-01-04 -1.192147 -0.452018  0.490220  0.607795  0.249342
# 2020-01-05  0.042078 -0.205100  0.336905 -1.363510  0.388651

# %%
df['D'].head(5)
# Out:
# 2020-01-01    0.057440
# 2020-01-02   -0.795155
# 2020-01-03    0.121914
# 2020-01-04    0.607795
# 2020-01-05   -1.363510
# Freq: D, Name: D, dtype: float64

# %%
df[1:5]
# Out:
#                    A         B         C         D         E
# 2020-01-02  0.328071  0.796712 -0.064047 -0.795155 -0.447193
# 2020-01-03 -0.800781 -1.367413  0.845610  0.121914  0.595674
# 2020-01-04 -1.192147 -0.452018  0.490220  0.607795  0.249342
# 2020-01-05  0.042078 -0.205100  0.336905 -1.363510  0.388651

# %%
df.loc[:,['B', 'C', 'D']]
# Out:
#                    B         C         D
# 2020-01-01  2.307343  0.309759  0.057440
# 2020-01-02  0.796712 -0.064047 -0.795155
# 2020-01-03 -1.367413  0.845610  0.121914
# 2020-01-04 -0.452018  0.490220  0.607795
# 2020-01-05 -0.205100  0.336905 -1.363510
# ...              ...       ...       ...
# 2021-08-18  0.239141  0.038178 -0.572336
# 2021-08-19  0.660418 -1.046074  0.275465
# 2021-08-20 -0.233522  0.022355 -1.633848
# 2021-08-21 -2.804051 -0.014137 -0.313572
# 2021-08-22  0.118458 -0.490430  0.170100
#
# [600 rows x 3 columns]

# %%
f = df.loc['20200301':'20200910', ['A', 'E']]
len(f)
# Out:
# 194

# %%
df.iloc[2:4, 0:2] # Pegar indice e colunas
# Out:
#                    A         B
# 2020-01-03 -0.800781 -1.367413
# 2020-01-04 -1.192147 -0.452018

# %%
df.iloc[[1,5,6], [0,3]] # Especificar quais linhas e colunas
# Out:
#                    A         D
# 2020-01-02  0.328071 -0.795155
# 2020-01-06  0.788483 -0.625794
# 2020-01-07 -0.226241  0.473373

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D         E
# 2020-01-02  0.328071  0.796712 -0.064047 -0.795155 -0.447193
# 2020-01-03 -0.800781 -1.367413  0.845610  0.121914  0.595674

# %%
df.head(5)
# Out:
#                    A         B         C         D         E
# 2020-01-01 -1.125108  2.307343  0.309759  0.057440 -1.616780
# 2020-01-02  0.328071  0.796712 -0.064047 -0.795155 -0.447193
# 2020-01-03 -0.800781 -1.367413  0.845610  0.121914  0.595674
# 2020-01-04 -1.192147 -0.452018  0.490220  0.607795  0.249342
# 2020-01-05  0.042078 -0.205100  0.336905 -1.363510  0.388651

# %%
df.A # Pega todos os dados da coluna A
# Out:
# 2020-01-01   -1.125108
# 2020-01-02    0.328071
# 2020-01-03   -0.800781
# 2020-01-04   -1.192147
# 2020-01-05    0.042078
#                 ...
# 2021-08-18    0.194816
# 2021-08-19   -0.670605
# 2021-08-20   -0.945427
# 2021-08-21   -0.917940
# 2021-08-22    1.532617
# Freq: D, Name: A, Length: 600, dtype: float64

# %%
df[df.A > 0] # Somente valores maiores que 0 na coluna A
# Out:
#                    A         B         C         D         E
# 2020-01-02  0.328071  0.796712 -0.064047 -0.795155 -0.447193
# 2020-01-05  0.042078 -0.205100  0.336905 -1.363510  0.388651
# 2020-01-06  0.788483  1.232034 -0.220683 -0.625794  0.827074
# 2020-01-10  0.120522  0.679982 -0.307862 -1.104806  0.854723
# 2020-01-11  0.627920 -0.004691 -1.564905  0.350772 -0.379046
# ...              ...       ...       ...       ...       ...
# 2021-08-13  0.471784  0.348944 -0.088261 -1.828924 -0.883824
# 2021-08-15  0.825575 -2.091268 -0.467494  0.156743  0.481548
# 2021-08-17  0.264216  0.083393 -0.763596  1.405741 -0.353592
# 2021-08-18  0.194816  0.239141  0.038178 -0.572336 -0.701073
# 2021-08-22  1.532617  0.118458 -0.490430  0.170100  1.967407
#
# [303 rows x 5 columns]

# %%
df[df > 0] # Retornar somente valores positivos. Negativos virão como "Not a Number"
# Out:
#                    A         B         C         D         E
# 2020-01-01       NaN  2.307343  0.309759  0.057440       NaN
# 2020-01-02  0.328071  0.796712       NaN       NaN       NaN
# 2020-01-03       NaN       NaN  0.845610  0.121914  0.595674
# 2020-01-04       NaN       NaN  0.490220  0.607795  0.249342
# 2020-01-05  0.042078       NaN  0.336905       NaN  0.388651
# ...              ...       ...       ...       ...       ...
# 2021-08-18  0.194816  0.239141  0.038178       NaN       NaN
# 2021-08-19       NaN  0.660418       NaN  0.275465       NaN
# 2021-08-20       NaN       NaN  0.022355       NaN       NaN
# 2021-08-21       NaN       NaN       NaN       NaN  0.863893
# 2021-08-22  1.532617  0.118458       NaN  0.170100  1.967407
#
# [600 rows x 5 columns]
