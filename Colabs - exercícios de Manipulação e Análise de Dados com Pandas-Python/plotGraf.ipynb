# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-39f510d45dca> in <module>()
# ----> 1 plt.style.use()
#
# TypeError: use() missing 1 required positional argument: 'style'

# %%
plt.rcParams['figure.figsize'] = (18,9) # Definir tamanho da figura

# %%
d = pd.read_csv('titanic_train.csv')
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d.shape
# Out:
# (891, 12)

# %%
plt.plot(d.Age, '*-r')
plt.title('Informações dos passageiros do Titanic', size=14)
plt.xlabel('Passageiro', size=12)
plt.ylabel('Idade', size=12)
plt.show()

# %%
d.Age.plot()
plt.xlabel('Passageiro', size=12)
plt.ylabel('Idade', size=12)
plt.show()

# %%
d.plot()
plt.show()

# %%
# Scatter plot
plt.scatter(d.PassengerId, d.Age, color='blue', marker='>')
plt.show()

# %%
d.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#Histogramas
# d.head(3)
d.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
d.Age.hist()
plt.xlabel('Idade')
plt.ylabel("Frequência Observada")
plt.savefig('nome_fig.png', transparent=True) # Salvar gráfico com transparência
plt.show()
