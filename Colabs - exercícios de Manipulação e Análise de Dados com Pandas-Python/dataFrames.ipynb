# %%
import pandas as pd
import numpy as np

# %%
series = pd.Series([7,4,2,np.nan,6,9])
series
# Out:
# 0    7.0
# 1    4.0
# 2    2.0
# 3    NaN
# 4    6.0
# 5    9.0
# dtype: float64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
datas = pd.date_range('20180101', periods=6, freq="D")
datas
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=datas, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2018-01-01 -0.387639 -0.064755 -0.355972  0.359913
# 2018-01-02 -0.261100 -0.596519 -0.287519 -0.552122
# 2018-01-03  0.533526 -2.035183 -0.217874 -0.862472
# 2018-01-04 -0.103789  0.453233  0.556034  1.521637
# 2018-01-05 -0.218309  0.107077 -1.296584  0.079435
# 2018-01-06  1.687025  0.405266  1.779095 -0.962566

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = pd.DataFrame({"A": 7,
                    "B": pd.Timestamp('20190101'),
                    "C": pd.Series(1, index=list(range(4)), dtype='float32'),
                    "D": np.array([3] * 4, dtype='int32'),
                    "E": pd.Categorical(["test","train","test","train"]),
                    "F": 'Python'
                    })
df2
# Out:
#    A          B    C  D      E       F
# 0  7 2019-01-01  1.0  3   test  Python
# 1  7 2019-01-01  1.0  3  train  Python
# 2  7 2019-01-01  1.0  3   test  Python
# 3  7 2019-01-01  1.0  3  train  Python

# %%
df2.dtypes
# Out:
# A             int64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head(2)
# Out:
#                    A         B         C         D
# 2018-01-01 -0.387639 -0.064755 -0.355972  0.359913
# 2018-01-02 -0.261100 -0.596519 -0.287519 -0.552122

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2018-01-04 -0.103789  0.453233  0.556034  1.521637
# 2018-01-05 -0.218309  0.107077 -1.296584  0.079435
# 2018-01-06  1.687025  0.405266  1.779095 -0.962566

# %%
df.index
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[-0.38763864, -0.0647553 , -0.35597168,  0.35991259],
#        [-0.26109983, -0.59651883, -0.28751872, -0.55212202],
#        [ 0.53352551, -2.03518265, -0.21787441, -0.86247185],
#        [-0.10378851,  0.4532327 ,  0.55603431,  1.52163671],
#        [-0.21830861,  0.10707675, -1.2965838 ,  0.07943509],
#        [ 1.68702486,  0.40526585,  1.77909536, -0.96256614]])

# %%
df.T
# Out:
#    2018-01-01  2018-01-02  2018-01-03  2018-01-04  2018-01-05  2018-01-06
# A   -0.387639   -0.261100    0.533526   -0.103789   -0.218309    1.687025
# B   -0.064755   -0.596519   -2.035183    0.453233    0.107077    0.405266
# C   -0.355972   -0.287519   -0.217874    0.556034   -1.296584    1.779095
# D    0.359913   -0.552122   -0.862472    1.521637    0.079435   -0.962566

# %%
df2.T
# Out:
#                      0                    1                    2  \
# A                    7                    7                    7
# B  2019-01-01 00:00:00  2019-01-01 00:00:00  2019-01-01 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 test                train                 test
# F               Python               Python               Python
#
#                      3
# A                    7
# B  2019-01-01 00:00:00
# C                  1.0
# D                    3
# E                train
# F               Python

# %%
df2.to_numpy()
# Out:
# array([[7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'test', 'Python'],
#        [7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'train', 'Python'],
#        [7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'test', 'Python'],
#        [7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'train', 'Python']],
#       dtype=object)
