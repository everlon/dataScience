# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20220101', periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=datas, columns=['Var_A', 'Var_B', 'Var_C', 'Var_D'])

# %%
df
# Out:
#                Var_A     Var_B     Var_C     Var_D
# 2022-01-01  0.616543  0.695579 -0.424585  1.687486
# 2022-01-02  1.186882  2.053243  0.598328  0.590313
# 2022-01-03  0.656180 -1.071695  1.099262  1.389365
# 2022-01-04  1.436767 -0.834872  0.232596 -0.839150
# 2022-01-05 -0.653180 -0.238752  0.062589 -1.007159
# 2022-01-06  1.259364  1.700905  0.880811 -0.790401

# %%
dft = df.T # Transpor
dft
# Out:
#        2022-01-01  2022-01-02  2022-01-03  2022-01-04  2022-01-05  2022-01-06
# Var_A    0.616543    1.186882    0.656180    1.436767   -0.653180    1.259364
# Var_B    0.695579    2.053243   -1.071695   -0.834872   -0.238752    1.700905
# Var_C   -0.424585    0.598328    1.099262    0.232596    0.062589    0.880811
# Var_D    1.687486    0.590313    1.389365   -0.839150   -1.007159   -0.790401

# %%
df.shape # Número de colunas e linhas
# Out:
# (6, 4)

# %%
v = dft.values
v
# Out:
# array([[ 0.61654311,  1.18688228,  0.65617998,  1.43676736, -0.6531796 ,
#          1.25936431],
#        [ 0.69557914,  2.05324268, -1.07169458, -0.83487181, -0.23875155,
#          1.70090458],
#        [-0.42458471,  0.59832837,  1.09926203,  0.23259601,  0.06258916,
#          0.88081069],
#        [ 1.68748558,  0.59031285,  1.38936457, -0.83915025, -1.00715879,
#         -0.79040119]])

# %%
np.size(v)
# Out:
# 24

# %%
v.reshape((3,12))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-a80c3c55fbc0> in <module>()
# ----> 1 v.reshape((3,12))
#
# ValueError: cannot reshape array of size 24 into shape (3,12)
