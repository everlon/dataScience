# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20200101', periods=60, freq="D")
df = pd.DataFrame(np.random.randn(60,5), index=datas, columns=list("ABCDE"))
df.shape
# Out:
# (60, 5)

# %%
df.head(3)
# Out:
#                    A         B         C         D         E
# 2020-01-01  0.137191 -1.237636  0.504851 -1.580450 -0.348793
# 2020-01-02 -0.279513  0.682350  0.510628  0.994224  0.088696
# 2020-01-03  1.671680  1.159697  1.155913 -0.453833 -0.031029

# %%
df['F'] = 1
df.head(5)
# Out:
#                    A         B         C         D         E  F
# 2020-01-01  0.137191 -1.237636  0.504851 -1.580450 -0.348793  1
# 2020-01-02 -0.279513  0.682350  0.510628  0.994224  0.088696  1
# 2020-01-03  1.671680  1.159697  1.155913 -0.453833 -0.031029  1
# 2020-01-04  1.291695 -0.269815 -0.036226  0.898561  0.552190  1
# 2020-01-05  1.810498  0.840345  0.511860 -0.510035 -0.712536  1

# %%
df['G'] = range(60)
df.head(15)
# Out:
#                    A         B         C         D         E  F   G
# 2020-01-01  0.137191 -1.237636  0.504851 -1.580450 -0.348793  1   0
# 2020-01-02 -0.279513  0.682350  0.510628  0.994224  0.088696  1   1
# 2020-01-03  1.671680  1.159697  1.155913 -0.453833 -0.031029  1   2
# 2020-01-04  1.291695 -0.269815 -0.036226  0.898561  0.552190  1   3
# 2020-01-05  1.810498  0.840345  0.511860 -0.510035 -0.712536  1   4
# 2020-01-06 -0.770560 -1.305899 -0.704127  0.268963  1.855229  1   5
# 2020-01-07  2.035921 -0.039018  0.497435  0.824505  0.129587  1   6
# 2020-01-08 -0.793672  1.204503  1.547037  0.487943 -1.358484  1   7
# 2020-01-09 -0.272986 -0.875575  0.844811  0.936613 -1.358097  1   8
# 2020-01-10 -0.642250 -0.136844 -1.037351  1.595425 -0.443399  1   9
# 2020-01-11 -0.031235  0.754250 -0.093414 -0.317656 -0.556816  1  10
# 2020-01-12 -0.367703 -0.802735 -0.263489  0.930035  0.365553  1  11
# 2020-01-13 -0.549005 -0.966036 -0.153069 -1.451262 -0.311256  1  12
# 2020-01-14  2.541495 -1.542808 -0.919215 -0.225032 -0.266220  1  13
# 2020-01-15 -1.409513 -0.143963  1.425809 -0.454276 -0.507369  1  14

# %%
df['Produto'] = df['A'] * df['B']
df.head(3)
# Out:
#                    A         B         C         D         E  F  G   Produto
# 2020-01-01  0.137191 -1.237636  0.504851 -1.580450 -0.348793  1  0 -0.169792
# 2020-01-02 -0.279513  0.682350  0.510628  0.994224  0.088696  1  1 -0.190725
# 2020-01-03  1.671680  1.159697  1.155913 -0.453833 -0.031029  1  2  1.938643

# %%
0.137191 * -1.237636
# Out:
# -0.169792520476
